# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gmaps
import gmaps.datasets
from scipy.stats import linregress
from config import g_key

# %%
total_crime_rates = pd.read_csv("CSV_Files/Crime_Rates/total_crime_rates.csv")
total_crime_rates
# Out:
#                            Unnamed: 0 State        ORI  \
# 0            BOSTON POLICE DEPARTMENT    MA  MA0130100
# 1         CHARLOTTESVILLE POLICE DEPT    VA  VA1020000
# 2       CHATTANOOGA POLICE DEPARTMENT    TN  TN0330100
# 3                 CHICAGO POLICE DEPT    IL  ILCPD0000
# 4            DALLAS POLICE DEPARTMENT    TX  TXDPD0000
# 5            DENVER POLICE DEPARTMENT    CO  CODPD0000
# 6       KANSAS CITY POLICE DEPARTMENT    MO  MOKPD0000
# 7   LAS VEGAS METRO POLICE DEPARTMENT    NV  NV0020100
# 8       NEW ORLEANS POLICE DEPARTMENT    LA  LANPD0000
# 9              PORTLAND POLICE BUREAU    OR  OR0260200
# 10    SAN FRANCISCO POLICE DEPARTMENT    CA  CA0380100
# 11      SIOUX FALLS POLICE DEPARTMENT    SD  SD0490200
#
#                        City, State  Population  Total Crime  \
# 0       Boston city, Massachusetts    679413.0        34958
# 1   Charlottesville city, Virginia     47042.0         2591
# 2      Chattanooga city, Tennessee    177365.0        24263
# ...

# %%
#renaming Unnamed: 0 column name
total_crime_rates = total_crime_rates.rename(columns={"Unnamed: 0": "Police Department"})
total_crime_rates
# Out:
#                     Police Department State        ORI  \
# 0            BOSTON POLICE DEPARTMENT    MA  MA0130100
# 1         CHARLOTTESVILLE POLICE DEPT    VA  VA1020000
# 2       CHATTANOOGA POLICE DEPARTMENT    TN  TN0330100
# 3                 CHICAGO POLICE DEPT    IL  ILCPD0000
# 4            DALLAS POLICE DEPARTMENT    TX  TXDPD0000
# 5            DENVER POLICE DEPARTMENT    CO  CODPD0000
# 6       KANSAS CITY POLICE DEPARTMENT    MO  MOKPD0000
# 7   LAS VEGAS METRO POLICE DEPARTMENT    NV  NV0020100
# 8       NEW ORLEANS POLICE DEPARTMENT    LA  LANPD0000
# 9              PORTLAND POLICE BUREAU    OR  OR0260200
# 10    SAN FRANCISCO POLICE DEPARTMENT    CA  CA0380100
# 11      SIOUX FALLS POLICE DEPARTMENT    SD  SD0490200
#
#                        City, State  Population  Total Crime  \
# 0       Boston city, Massachusetts    679413.0        34958
# 1   Charlottesville city, Virginia     47042.0         2591
# 2      Chattanooga city, Tennessee    177365.0        24263
# ...

# %%
hotel_ratings = pd.read_csv("CSV_Files/avg_hotel_rating.csv")
hotel_ratings
# Out:
#    State  Hotel Rating
# 0     CA          4.12
# 1     IL          4.35
# 2     LA          4.42
# 3     MA          4.43
# 4     MO          4.31
# 5     NV          4.12
# 6     OR          4.40
# 7     SD          4.33
# 8     TN          4.26
# 9     TX          4.34
# 10    VA          4.15

# %%
#map with info box of total crimes and average hotel rating per city
gmaps.configure(api_key=g_key)
hotel_list = [{"City": "Kansas City", "location": (39.09973, -94.57857), "Average Hotel Rating": 4.26, "Total Crime Rate": 10970.73},
             {"City": "New Orleans", "location": (29.95465, -90.07507), "Average Hotel Rating": 4.24, "Total Crime Rate": 13034.74}, 
             {"City": "Dallas", "location": (32.78306, -96.80667), "Average Hotel Rating": 4.29, "Total Crime Rate": 8713.10}, 
             {"City": "Portland", "location": (45.52345, -122.67621), "Average Hotel Rating": 4.42, "Total Crime Rate": 11986.63},
             {"City": "Charlottesville", "location": (38.0293059, -78.4766781), "Average Hotel Rating": 4.24, "Total Crime Rate": 5507.84}, 
             {"City": "Chicago", "location": (41.85003, -87.65005), "Average Hotel Rating": 4.3, "Total Crime Rate": 7818.41},
             {"City": "Denver", "location": (39.73915, -104.9847), "Average Hotel Rating": 4.38, "Total Crime Rate": 9528.75},
             {"City": "Sioux Falls", "location": (43.54997, -96.70033), "Average Hotel Rating": 4.42, "Total Crime Rate": 7596.85},
             {"City": "Las Vegas", "location": (36.17497, -115.13722), "Average Hotel Rating": 4.34, "Total Crime Rate": 17585.93},
             {"City": "San Francisco", "location": (37.77493, -122.41942), "Average Hotel Rating": 4.17, "Total Crime Rate": 12583.50},
             {"City": "Chattanooga", "location": (35.04563, -85.30968), "Average Hotel Rating": 4.33, "Total Crime Rate": 13679.70},
             {"City": "Boston", "location": (42.35843, -71.05977), "Average Hotel Rating": 4.26, "Total Crime Rate": 5145.32}]

hotel_locations = [hotel["location"] for hotel in hotel_list]
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Average Hotel Rating</dt><dd>{Average Hotel Rating}</dd>
<dt>Total Crime Rate</dt><dd>{Total Crime Rate}</dd>
</dl>
"""
hotel_info = [info_box_template.format(**hotel) for hotel in hotel_list] 
marker_layer = gmaps.marker_layer(hotel_locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#map displaying city, average hotel rating and population
gmaps.configure(api_key=g_key)
hotel_list = [{"City": "Kansas City", "location": (39.09973, -94.57857), "Average Hotel Rating": 4.26, "Population": 481417},
             {"City": "New Orleans", "location": (29.95465, -90.07507), "Average Hotel Rating": 4.24, "Population": 389648}, 
             {"City": "Dallas", "location": (32.78306, -96.80667), "Average Hotel Rating": 4.29, "Population": 1318806}, 
             {"City": "Portland", "location": (45.52345, -122.67621), "Average Hotel Rating": 4.42, "Population": 639387},
             {"City": "Charlottesville", "location": (38.0293059, -78.4766781), "Average Hotel Rating": 4.24, "Population": 47042}, 
             {"City": "Chicago", "location": (41.85003, -87.65005), "Average Hotel Rating": 4.3, "Population": 2718555},
             {"City": "Denver", "location": (39.73915, -104.9847), "Average Hotel Rating": 4.38, "Population": 693417},
             {"City": "Sioux Falls", "location": (43.54997, -96.70033), "Average Hotel Rating": 4.42, "Population": 174151},
             {"City": "Las Vegas", "location": (36.17497, -115.13722), "Average Hotel Rating": 4.34, "Population": 626637},
             {"City": "San Francisco", "location": (37.77493, -122.41942), "Average Hotel Rating": 4.17, "Population": 870044},
             {"City": "Chattanooga", "location": (35.04563, -85.30968), "Average Hotel Rating": 4.33, "Population": 177365},
             {"City": "Boston", "location": (42.35843, -71.05977), "Average Hotel Rating": 4.26, "Population": 679413}]

hotel_locations = [hotel["location"] for hotel in hotel_list]
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Average Hotel Rating</dt><dd>{Average Hotel Rating}</dd>
<dt>Population</dt><dd>{Population}</dd>
</dl>
"""
hotel_info = [info_box_template.format(**hotel) for hotel in hotel_list] 
marker_layer = gmaps.marker_layer(hotel_locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#merge on State
rating_crime_df = pd.merge(hotel_ratings, total_crime_rates, on="State")
rating_crime_df
# Out:
#    State  Hotel Rating                  Police Department        ORI  \
# 0     CA          4.12    SAN FRANCISCO POLICE DEPARTMENT  CA0380100
# 1     IL          4.35                CHICAGO POLICE DEPT  ILCPD0000
# 2     LA          4.42      NEW ORLEANS POLICE DEPARTMENT  LANPD0000
# 3     MA          4.43           BOSTON POLICE DEPARTMENT  MA0130100
# 4     MO          4.31      KANSAS CITY POLICE DEPARTMENT  MOKPD0000
# 5     NV          4.12  LAS VEGAS METRO POLICE DEPARTMENT  NV0020100
# 6     OR          4.40             PORTLAND POLICE BUREAU  OR0260200
# 7     SD          4.33      SIOUX FALLS POLICE DEPARTMENT  SD0490200
# 8     TN          4.26      CHATTANOOGA POLICE DEPARTMENT  TN0330100
# 9     TX          4.34           DALLAS POLICE DEPARTMENT  TXDPD0000
# 10    VA          4.15        CHARLOTTESVILLE POLICE DEPT  VA1020000
#
#                        City, State  Population  Total Crime  \
# 0   San Francisco city, California    870044.0       109482
# ...

# %%
#population bar chart
x_values = total_crime_rates["City, State"]
y_values = total_crime_rates["Population"]
plt.barh(x_values, y_values)
plt.title("Total Population Per City")
plt.xlabel("Total Population (Millions)")
plt.show()

# %%
#Total Crime vs Hotel Rating scatter plot 
plt.scatter(rating_crime_df["Hotel Rating"], rating_crime_df["Total Crime Rate"], marker="o", color="indigo")
plt.title("Total Crime vs Average Hotel Rating")
plt.xlabel("Average Hotel Rating")
plt.ylabel("Total Crime")
plt.savefig("TotalCrimevsHotelRating.png")
plt.grid()
plt.show()

# %%
#Total Crime vs Hotel Rating linear regression
x_values = rating_crime_df["Hotel Rating"]
y_values = rating_crime_df["Total Crime Rate"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Total Crime Rate vs Average Hotel Rating")
plt.xlabel("Average Hotel Rating")
plt.ylabel("Total Crime Rate")
plt.annotate(line_equation,(4.15,16000), fontsize=14, color="red")
plt.savefig("TotalCrimevsHotelRatingLinear.png")
plt.grid()
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.12462386472437624

# %%
#Total Property Crime vs Hotel Rating scatter plot 
plt.scatter(rating_crime_df["Hotel Rating"], rating_crime_df["Total Property Crime Rate"], marker="o", color="indigo")
plt.title("Total Property Crime Rate vs Average Hotel Rating")
plt.xlabel("Average Hotel Rating")
plt.ylabel("Total Property Crime Rate")
plt.savefig("PropertyCrimevsHotelRating.png")
plt.grid()
plt.show()

# %%
#Total Property Crime vs Hotel Rating linear regression
x_values = rating_crime_df["Hotel Rating"]
y_values = rating_crime_df["Total Property Crime Rate"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Total Property Crime Rate vs Average Hotel Rating")
plt.xlabel("Average Hotel Rating")
plt.ylabel("Total Property Crime Rate")
plt.annotate(line_equation,(4.15,13000), fontsize=14, color="red")
plt.savefig("PropertyCrimevsHotelRatingLinear.png")
plt.grid()
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.15215743391339148

# %%
#Total Person Crime vs Hotel Rating scatter plot 
plt.scatter(rating_crime_df["Hotel Rating"], rating_crime_df["Total Person Crime Rate"], marker="o", color="indigo")
plt.title("Total Person Crime Rate vs Average Hotel Rating")
plt.xlabel("Average Hotel Rating")
plt.ylabel("Total Person Crime Rate")
plt.savefig("PersonCrimevsHotelRating.png")
plt.grid()
plt.show()

# %%
#Total Person Crime vs Hotel Rating linear regression
x_values = rating_crime_df["Hotel Rating"]
y_values = rating_crime_df["Total Person Crime Rate"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Total Person Crime Rate vs Average Hotel Rating")
plt.xlabel("Average Hotel Rating")
plt.ylabel("Total Person Crime Rate")
plt.annotate(line_equation,(4.20,2500), fontsize=14, color="red")
plt.savefig("PersonCrimevsHotelRatingLinear.png")
plt.grid()
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.002033528976653611

# %%
#Total Crimes in 2019 Per Police Department in each city
x_values = total_crime_rates["Police Department"]
y_values = total_crime_rates["Total Crime"]
plt.barh(x_values, y_values)
plt.title("Total Crimes in 2019 Per Police Department")
plt.xlabel("Total Number of Crimes")
plt.savefig("TotalCrimesperDept.png")
plt.show()

# %%
# Total Person Crime and Property Crime 
person_rate = total_crime_rates["Total Person Crime"]
property_rate = total_crime_rates["Total Property Crime"]
index = total_crime_rates["Police Department"]
df = pd.DataFrame({"Total Person Crime per PD": person_rate, "Total Property Crime per PD": property_rate})

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.index = index

# %%
ax = df.plot.barh()

# %%
#Total Crime Rate in 2019 Per Police Department in each city
x_values = total_crime_rates["Police Department"]
y_values = total_crime_rates["Total Crime Rate"]
plt.barh(x_values, y_values)
plt.title("Total Crime Rate in 2019 Per Police Department")
plt.xlabel("Total Number of Crimes")
plt.savefig("TotalCrimeRateperDept.png")
plt.show()

# %%
#Total Person Crime Rate and Property Crime Rate
person_rate = total_crime_rates["Total Person Crime Rate"]
property_rate = total_crime_rates["Total Property Crime Rate"]
index = total_crime_rates["Police Department"]
df = pd.DataFrame({"Total Person Crime Rate": person_rate, "Total Property Crime Rate": property_rate})

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.index = index

# %%
ax = df.plot.barh()

# %%
#dataframe will detailing each offense and totals
pop_offense = pd.read_csv("CSV_Files/Crime_Rates/all_crime_rates.csv")
pop_offense
# Out:
#                            Unnamed: 0 State        ORI  \
# 0            BOSTON POLICE DEPARTMENT    MA  MA0130100
# 1         CHARLOTTESVILLE POLICE DEPT    VA  VA1020000
# 2       CHATTANOOGA POLICE DEPARTMENT    TN  TN0330100
# 3                 CHICAGO POLICE DEPT    IL  ILCPD0000
# 4            DALLAS POLICE DEPARTMENT    TX  TXDPD0000
# 5            DENVER POLICE DEPARTMENT    CO  CODPD0000
# 6       KANSAS CITY POLICE DEPARTMENT    MO  MOKPD0000
# 7   LAS VEGAS METRO POLICE DEPARTMENT    NV  NV0020100
# 8       NEW ORLEANS POLICE DEPARTMENT    LA  LANPD0000
# 9              PORTLAND POLICE BUREAU    OR  OR0260200
# 10    SAN FRANCISCO POLICE DEPARTMENT    CA  CA0380100
# 11      SIOUX FALLS POLICE DEPARTMENT    SD  SD0490200
#
#                        City, State  Population  Agg Assault  Arson  \
# 0       Boston city, Massachusetts    679413.0         2932      4
# 1   Charlottesville city, Virginia     47042.0          103      5
# ...

# %%
pop_offense = pop_offense.rename(columns={"Unnamed: 0": "Police Department"})
pop_offense
# Out:
#                     Police Department State        ORI  \
# 0            BOSTON POLICE DEPARTMENT    MA  MA0130100
# 1         CHARLOTTESVILLE POLICE DEPT    VA  VA1020000
# 2       CHATTANOOGA POLICE DEPARTMENT    TN  TN0330100
# 3                 CHICAGO POLICE DEPT    IL  ILCPD0000
# 4            DALLAS POLICE DEPARTMENT    TX  TXDPD0000
# 5            DENVER POLICE DEPARTMENT    CO  CODPD0000
# 6       KANSAS CITY POLICE DEPARTMENT    MO  MOKPD0000
# 7   LAS VEGAS METRO POLICE DEPARTMENT    NV  NV0020100
# 8       NEW ORLEANS POLICE DEPARTMENT    LA  LANPD0000
# 9              PORTLAND POLICE BUREAU    OR  OR0260200
# 10    SAN FRANCISCO POLICE DEPARTMENT    CA  CA0380100
# 11      SIOUX FALLS POLICE DEPARTMENT    SD  SD0490200
#
#                        City, State  Population  Agg Assault  Arson  \
# 0       Boston city, Massachusetts    679413.0         2932      4
# 1   Charlottesville city, Virginia     47042.0          103      5
# ...

# %%
#comparing Charlottesville and Boston total crime and total crime rate
ma_va = pop_offense.loc[pop_offense["State"].isin(["MA", "VA"])]
ma_va
# Out:
#              Police Department State        ORI  \
# 0     BOSTON POLICE DEPARTMENT    MA  MA0130100
# 1  CHARLOTTESVILLE POLICE DEPT    VA  VA1020000
#
#                       City, State  Population  Agg Assault  Arson  Auto Theft  \
# 0      Boston city, Massachusetts    679413.0         2932      4         920
# 1  Charlottesville city, Virginia     47042.0          103      5          78
#
#    Burglary  Homicide  ...  Burglary Crime Rate  Homicide Crime Rate  \
# 0      1703        42  ...           250.657553             6.181807
# 1       122         0  ...           259.342715             0.000000
#
#    Larceny Crime Rate  Property Crime Rate  Robbery Crime Rate  \
# 0         1558.698465          1944.767027          152.926129
# 1         1964.202202          2389.354194           46.766719
#
#    Sex Crimes Rate  Violent Crime Rate  Total Crime Rate  \
# 0        33.999938          630.544308       5145.323978
# 1        68.024319          384.762553       5507.844054
#
# ...

# %%
x_values = ma_va["City, State"]
y_values = ma_va["Total Crime"]
plt.bar(x_values, y_values)
plt.title("Total Crimes in Charlottesville and Boston")
plt.ylabel("Total Number of Crimes")
plt.savefig("TotalCrimesperMAVA.png")
plt.show()

# %%
x_values = ma_va["City, State"]
y_values = ma_va["Total Crime Rate"]
plt.bar(x_values, y_values)
plt.title("Total Crime Rate in Charlottesville and Boston")
plt.ylabel("Total Crime Rate")
plt.savefig("TotalCrimeRateperMAVA.png")
plt.show()

# %%
#scatter plot total crime vs population
plt.scatter(total_crime_rates["Population"], total_crime_rates["Total Crime Rate"], marker="o", color="indigo")
plt.title("Total Crime Rate vs Population")
plt.xlabel("Population")
plt.ylabel("Total Crime Rate")
plt.savefig("TotalCrimevsPop.png")
plt.grid()
plt.show()

# %%
#Total Crime Rate vs Population linear regression
x_values = total_crime_rates["Population"]
y_values = total_crime_rates["Total Crime Rate"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Total Crime Rate vs Population")
plt.xlabel("Population")
plt.ylabel("Total Crime Rate")
plt.annotate(line_equation,(2.0,14000), fontsize=14, color="red")
plt.savefig("TotalCrimeRatevsPopLinear.png")
plt.grid()
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.023138043355801514

# %%
#Total Crime Rate vs Population linear regression
x_values = total_crime_rates["Population"]
y_values = total_crime_rates["Total Crime"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Total Crime vs Population")
plt.xlabel("Population")
plt.ylabel("Total Crime")
plt.annotate(line_equation,(2.0,150000), fontsize=14, color="red")
plt.savefig("TotalCrimevsPopLinear.png")
plt.grid()
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.870195789442239

# %%
#scatter plot hotel rating vs population
plt.scatter(rating_crime_df["Population"], rating_crime_df["Hotel Rating"], marker="o", color="indigo")
plt.title("Average Hotel Rating vs Population")
plt.xlabel("Population")
plt.ylabel("Average Hotel Rating")
plt.savefig("HotelRatingvsPop.png")
plt.grid()
plt.show()

# %%
#Hotel Rating vs Population linear regression
x_values = rating_crime_df["Population"]
y_values = rating_crime_df["Hotel Rating"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Average Hotel Rating vs Population")
plt.xlabel("Population")
plt.ylabel("Average Hotel Rating")
plt.annotate(line_equation,(1.5, 4.2), fontsize=14, color="red")
plt.savefig("HotelvsPopLinear.png")
plt.grid()
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.03643507259802325
