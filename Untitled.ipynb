# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gmaps
from scipy.stats import linregress
from config import g_key

# %%
total_crime_rates = pd.read_csv("CSV_Files/Crime_Rates/total_crime_rates.csv")
total_crime_rates
# Out:
#                            Unnamed: 0 State        ORI  \
# 0            BOSTON POLICE DEPARTMENT    MA  MA0130100
# 1         CHARLOTTESVILLE POLICE DEPT    VA  VA1020000
# 2       CHATTANOOGA POLICE DEPARTMENT    TN  TN0330100
# 3                 CHICAGO POLICE DEPT    IL  ILCPD0000
# 4            DALLAS POLICE DEPARTMENT    TX  TXDPD0000
# 5            DENVER POLICE DEPARTMENT    CO  CODPD0000
# 6       KANSAS CITY POLICE DEPARTMENT    MO  MOKPD0000
# 7   LAS VEGAS METRO POLICE DEPARTMENT    NV  NV0020100
# 8       NEW ORLEANS POLICE DEPARTMENT    LA  LANPD0000
# 9              PORTLAND POLICE BUREAU    OR  OR0260200
# 10    SAN FRANCISCO POLICE DEPARTMENT    CA  CA0380100
# 11      SIOUX FALLS POLICE DEPARTMENT    SD  SD0490200
#
#                        City, State  Population  Total Crime  \
# 0       Boston city, Massachusetts    679413.0        34958
# 1   Charlottesville city, Virginia     47042.0         2591
# 2      Chattanooga city, Tennessee    177365.0        24263
# 3           Chicago city, Illinois   2718555.0       212548
# 4               Dallas city, Texas   1318806.0       114909
# 5            Denver city, Colorado    693417.0        66074
# 6       Kansas City city, Missouri    481417.0        52815
# 7           Las Vegas city, Nevada    626637.0       110200
# 8      New Orleans city, Louisiana    389648.0        50790
# 9            Portland city, Oregon    639387.0        76641
# 10  San Francisco city, California    870044.0       109482
# 11  Sioux Falls city, South Dakota    174151.0        13230
#
#     Total Person Crime  Total Property Crime  Total Crime Rate  \
# 0                 8528                 26430       5145.323978
# 1                  338                  2253       5507.844054
# 2                 4026                 20237      13679.700054
# 3                51064                161484       7818.418241
# 4                24207                 90702       8713.108676
# 5                11391                 54683       9528.753982
# 6                14407                 38408      10970.738466
# 7                17708                 92492      17585.938909
# 8                 9032                 41758      13034.841703
# 9                 7485                 69156      11986.637201
# 10               11866                 97616      12583.501524
# 11                1895                 11335       7596.855602
#
#     Total Person Crime Rate  Total Property Crime Rate
# 0               1255.201181                3890.122797
# 1                718.506866                4789.337188
# 2               2269.895413               11409.804640
# 3               1878.350815                5940.067426
# 4               1835.523951                6877.584724
# 5               1642.734458                7886.019524
# 6               2992.623858                7978.114608
# 7               2825.878459               14760.060450
# 8               2317.989570               10716.852133
# 9               1170.652516               10815.984685
# 10              1363.839070               11219.662454
# 11              1088.136158                6508.719445

# %%
hotel_ratings = pd.read_csv("CSV_Files/total_hotel_rating.csv")
hotel_ratings
# Out:
#                                                  Hotel        Lat        Lng  \
# 0              Kansas City Marriott Country Club Plaza  39.046192 -94.586508
# 1    Hotel Phillips Kansas City, Curio Collection b...  39.100119 -94.584701
# 2    816 Hotel Westport Country Club Plaza, Ascend ...  39.051005 -94.595609
# 3                                         The Fontaine  39.040071 -94.598495
# 4          Embassy Suites by Hilton Kansas City- Plaza  39.049781 -94.589446
# ..                                                 ...        ...        ...
# 228        Cambria Hotel Boston, Downtown-South Boston  42.343169 -71.056969
# 229                            InterContinental Boston  42.353691 -71.051913
# 230                               Moxy Boston Downtown  42.350861 -71.064680
# 231                Hilton Boston Downtown/Faneuil Hall  42.357264 -71.053441
# 232                       The Westin Boston Waterfront  42.345993 -71.043010
#
#      Hotel Rating                       Address State
# 0             4.4     4445 Main St, Kansas City    MO
# 1             4.1    106 W 12th St, Kansas City    MO
# 2             3.7  801 Westport Rd, Kansas City    MO
# 3             4.3    901 W 48th Pl, Kansas City    MO
# 4             3.7    220 W 43rd St, Kansas City    MO
# ..            ...                           ...   ...
# 228           3.5          6 W Broadway, Boston    MA
# 229           4.6      510 Atlantic Ave, Boston    MA
# 230           4.3        240 Tremont St, Boston    MA
# 231           4.3           89 Broad St, Boston    MA
# 232           4.4         425 Summer St, Boston    MA
#
# [233 rows x 6 columns]

# %%
#hotel markers
gmaps.configure(api_key=g_key)
locations = hotel_ratings[["Lat", "Lng"]].astype(float)
fig = gmaps.figure()
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# # gmaps.configure(api_key=g_key)
# # locations = hotel_ratings[["Lat", "Lng"]].astype(float)
# # hotel_locations = [hotel["locations"] for hotel in hotel_ratings]
# info_box_template = """
# <dl>
# <dt>Hotel Name</dt><dd>{Hotel Name}</dd>
# <dt>Hotel Rating/dt><dd>{Hotel Rating}</dd>
# </dl>
# """
# hotel_info = [info_box_template.format(**hotel) for hotel in hotel_ratings] 
# marker_layer = gmaps.marker_layer(hotel_locations, info_box_template=hotel_info)
# fig = gmaps.figure()
# fig.add_layers(marker_layer)
# fig

# %%
#merge on State
rating_crime_df = pd.merge(hotel_ratings, total_crime_rates, on="State")
rating_crime_df.head()
# Out:
#                                                Hotel        Lat        Lng  \
# 0            Kansas City Marriott Country Club Plaza  39.046192 -94.586508
# 1  Hotel Phillips Kansas City, Curio Collection b...  39.100119 -94.584701
# 2  816 Hotel Westport Country Club Plaza, Ascend ...  39.051005 -94.595609
# 3                                       The Fontaine  39.040071 -94.598495
# 4        Embassy Suites by Hilton Kansas City- Plaza  39.049781 -94.589446
#
#    Hotel Rating                       Address State  \
# 0           4.4     4445 Main St, Kansas City    MO
# 1           4.1    106 W 12th St, Kansas City    MO
# 2           3.7  801 Westport Rd, Kansas City    MO
# 3           4.3    901 W 48th Pl, Kansas City    MO
# 4           3.7    220 W 43rd St, Kansas City    MO
#
#                       Unnamed: 0        ORI                 City, State  \
# 0  KANSAS CITY POLICE DEPARTMENT  MOKPD0000  Kansas City city, Missouri
# 1  KANSAS CITY POLICE DEPARTMENT  MOKPD0000  Kansas City city, Missouri
# 2  KANSAS CITY POLICE DEPARTMENT  MOKPD0000  Kansas City city, Missouri
# 3  KANSAS CITY POLICE DEPARTMENT  MOKPD0000  Kansas City city, Missouri
# 4  KANSAS CITY POLICE DEPARTMENT  MOKPD0000  Kansas City city, Missouri
#
#    Population  Total Crime  Total Person Crime  Total Property Crime  \
# 0    481417.0        52815               14407                 38408
# 1    481417.0        52815               14407                 38408
# 2    481417.0        52815               14407                 38408
# 3    481417.0        52815               14407                 38408
# 4    481417.0        52815               14407                 38408
#
#    Total Crime Rate  Total Person Crime Rate  Total Property Crime Rate
# 0      10970.738466              2992.623858                7978.114608
# 1      10970.738466              2992.623858                7978.114608
# 2      10970.738466              2992.623858                7978.114608
# 3      10970.738466              2992.623858                7978.114608
# 4      10970.738466              2992.623858                7978.114608

# %%
#linear regression
x_values = rating_crime_df["Hotel Rating"]
y_values = rating_crime_df["Total Crime"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Total Crime vs Hotel Rating")
plt.xlabel("Hotel Rating")
plt.ylabel("Total Crime")
plt.annotate(line_equation,(3.25,150000), fontsize=14, color="red")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.0009229074678504802

# %%
x_values = total_crime_rates["Unnamed: 0"]
y_values = total_crime_rates["Total Crime"]
plt.barh(x_values, y_values)
plt.title("Total Crimes in 2019 Per Police Department")
plt.show()

# %%
index = total_crime_rates["Unnamed: 0"]
personcrime = total_crime_rates["Total Person Crime"]
propertycrime = total_crime_rates["Total Property Crime"]

df = pd.DataFrame({"Total Person Crime": personcrime, "Total Property Crime": propertycrime}, index=index)
ax=df.plot.barh()
